# %% [markdown]
# Create the DataFrame

# %%
data = [
    {
        "id": 1,
        "name": "Alice",
        "address": {
            "city": "New York",
            "zipcode": "10001"
        },
        "skills": ["Python", "Machine Learning"],
        "scores": {"math": 85, "science": 92}
    },
# Out:
# Sample DataFrame:
#    Student_ID  Hours_Studied  Attendance(%)  Sleep_Hours  Part_Time_Job  \
# 0           1              2             93            9              0
# 1           2             10             69            4              0
# 2           3             13             79            7              0
# 3           4             14             60            8              1
# 4           5              9             77            4              1
#
#    Extracurriculars Parent_Education_Level  Internet_Usage(hrs)  \
# 0                 1             Bachelor's                    2
# 1                 1               Master's                    2
# 2                 0             Bachelor's                    4
# 3                 1               Master's                    6
# 4                 0            High School                    7
#
#    Weekly_Revision(hrs)  Final_Score
# 0                     1           73
# 1                     4           54
# ...
